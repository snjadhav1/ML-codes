# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\Asus\OneDrive\Documents\Desktop\ML_FINAL\3rd\temperatures.csv")

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
months = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','AUG','NOV','DEC']

# %%
for month in months:
    print(f'\n==={month}===')

    X = df['YEAR'].values.reshape(-1,1)
    y = df[month].values

    X_train,X_test,y_train,y_test =train_test_split(X,y,test_size =0.25,random_state =42)

    model =LinearRegression()
    model.fit(X_train,y_train)

    y_pred =model.predict(X_test)

    #assscess the performance of the linear regression model
    mse = mean_squared_error(y_test,y_pred)
    mae = mean_absolute_error(y_test,y_pred)
    r2 = r2_score(y_test,y_pred)

    print('performance matrics')
    print(f'mean_squared_error:{mse:.2f}')
    print(f'mean_absolute_error:{mae:.2f}')
    print(f'r2_score:{r2:.2f}')

    plt.figure(figsize=(10,6))
    plt.scatter(X,y,color='blue',label=f'Actual {month} temperature')
    plt.plot(X_test,y_pred,color='red',linewidth=2,label ='Regression Line')
    plt.title(f'{month} Temperature prediction using linear regression')
    plt.xlabel('year')
    plt.ylabel(f'{month} temperature (Celsius)')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ===JAN===
# performance matrics
# mean_squared_error:0.53
# mean_absolute_error:0.52
# r2_score:0.42
# ===FEB===
# performance matrics
# mean_squared_error:0.71
# mean_absolute_error:0.59
# r2_score:0.55
# ===MAR===
# performance matrics
# mean_squared_error:0.98
# mean_absolute_error:0.77
# r2_score:0.35
# ===APR===
# performance matrics
# mean_squared_error:0.75
# mean_absolute_error:0.68
# r2_score:0.27
# ===MAY===
# performance matrics
# mean_squared_error:0.44
# mean_absolute_error:0.54
# r2_score:0.22
# ===JUN===
# performance matrics
# mean_squared_error:0.39
# mean_absolute_error:0.51
# r2_score:0.04
# ===JUL===
# performance matrics
# mean_squared_error:0.19
# mean_absolute_error:0.32
# r2_score:0.13
# ===AUG===
# performance matrics
# mean_squared_error:0.15
# mean_absolute_error:0.30
# r2_score:0.19
# ===SEP===
# performance matrics
# mean_squared_error:0.09
# mean_absolute_error:0.22
# r2_score:0.55
# ===AUG===
# performance matrics
# mean_squared_error:0.15
# ...
