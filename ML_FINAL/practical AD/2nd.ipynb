# %%
import pandas as pd
"""
This script imports the pandas library for data manipulation and analysis.

Modules:
    pandas (pd): A powerful data analysis and manipulation library for Python.

Usage:
    This script is intended to be used in a Jupyter Notebook (.ipynb) file.
"""

# %%
db = pd.read_csv(r"C:\Users\Asus\Downloads\TYIT_23_sj\TYIT_23_sj\practical _2\data.csv")

# %%
db
"""
This code snippet appears to be a part of a Jupyter Notebook file located at:
`/c:/Users/Asus/Downloads/TYIT_23_sj/TYIT_23_sj/practical_2/2nd.ipynb`.

The variable `db` is referenced, but its definition or usage is not provided in the selection.
"""
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
missing_values = db.isnull().sum()
"""
This script calculates and prints the number of missing values in each column of a DataFrame.

Steps:
1. Calculate the number of missing values in each column of the DataFrame `db` using the `isnull().sum()` method.
2. Print the resulting Series, which contains the count of missing values for each column.

Note:
- Ensure that the DataFrame `db` is defined and loaded with data before running this script.
"""
print(missing_values)
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
db['age_of_house'] = 2014 - db['yr_built']
"""
This code calculates the age of each house in the dataset and adds it as a new column 'age_of_house'.

The age is determined by subtracting the year the house was built ('yr_built') from the year 2014.

Parameters:
db (DataFrame): A pandas DataFrame containing a column 'yr_built' which represents the year each house was built.

Returns:
None: The DataFrame is modified in place to include the new column 'age_of_house'.
"""

# %%
db['age_of_house']
"""
This code snippet accesses the 'age_of_house' column from the DataFrame 'db'.

Assumptions:
- 'db' is a pandas DataFrame that has been previously defined.
- The DataFrame contains a column named 'age_of_house'.

Returns:
- A pandas Series representing the 'age_of_house' column from the DataFrame 'db'.
"""
# Out:
# 0       59
# 1       93
# 2       48
# 3       51
# 4       38
#         ..
# 4595    60
# 4596    31
# 4597     5
# 4598    40
# 4599    24
# Name: age_of_house, Length: 4600, dtype: int64

# %%
db['total_sqft_area'] = db['sqft_above'] * db['sqft_basement']
"""
Calculate the total square footage area by multiplying the square footage 
of the above-ground area with the square footage of the basement area.

The result is stored in the 'total_sqft_area' column of the DataFrame 'db'.

Assumptions:
- 'db' is a pandas DataFrame.
- 'sqft_above' and 'sqft_basement' are columns in the DataFrame 'db' 
    representing the square footage of the above-ground area and basement area, respectively.
"""

# %%
db['total_rooms'] = db['bedrooms']+db['bathrooms']         # add the new colunm
"""
Adds a new column 'total_rooms' to the DataFrame 'db' by summing the values of 'bedrooms' and 'bathrooms' columns.

Parameters:
db (DataFrame): The DataFrame containing 'bedrooms' and 'bathrooms' columns.

Returns:
None: The function modifies the DataFrame in place by adding the 'total_rooms' column.
"""

# %%
X = db[['age_of_house','total_sqft_area','total_rooms','floors','price']]
"""
This code snippet selects specific columns from a DataFrame `db` and assigns them to variables `X` and `Y`.

Variables:
    X (DataFrame): A DataFrame containing the columns 'age_of_house', 'total_sqft_area', 'total_rooms', 'floors', and 'price' from `db`.
    Y (Series): A Series containing the 'price' column from `db`.

Note:
    The variable `X` is intended to hold the features for a machine learning model, while `Y` holds the target variable.
"""
Y=db ['price']                                                                   # assign thje varibles in in X and add the Final output in Y

# %%
from sklearn.model_selection import train_test_split
"""
This script splits the dataset into training and testing sets using scikit-learn's train_test_split function.

Imports:
    from sklearn.model_selection import train_test_split: Imports the train_test_split function from scikit-learn.

Variables:
    X_train: The training subset of the features.
    X_test: The testing subset of the features.
    Y_train: The training subset of the target variable.
    Y_test: The testing subset of the target variable.

Functions:
    train_test_split(X, Y, test_size=0.2, random_state=42): Splits the dataset into training and testing sets.
        - X: Features dataset.
        - Y: Target variable dataset.
        - test_size: Proportion of the dataset to include in the test split (default is 0.2).
        - random_state: Controls the shuffling applied to the data before applying the split for reproducibility (default is 42).

Output:
    X_train.shape: Shape of the training features dataset.
    X_test.shape: Shape of the testing features dataset.
    Y_train.shape: Shape of the training target variable dataset.
    Y_test.shape: Shape of the testing target variable dataset.
"""
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
X_train.shape , X_test.shape ,Y_train.shape , Y_test.shape          #split to train and test data
# Out:
# ((3680, 5), (920, 5), (3680,), (920,))

# %%
from sklearn.linear_model import  LinearRegression
"""
This script demonstrates the use of the LinearRegression model from the sklearn library.

The script performs the following steps:
1. Imports the LinearRegression class from sklearn.linear_model.
2. Initializes a LinearRegression model.
3. Fits the model to the training data (X_train, Y_train).

Note:
- Ensure that X_train and Y_train are defined and contain the appropriate training data before fitting the model.
"""
model =LinearRegression()
model.fit(X_train,Y_train)                  #set the model with linear reggration to the test values
# Out:
# LinearRegression()

# %%
score=model.score(X_test,Y_test)
"""
Evaluates the model's performance on the test dataset and prints the R^2 score.

This function uses the `score` method of the model to calculate the R^2 score, 
which indicates how well the model's predictions match the actual data. 
The R^2 score is then printed to the console.

Variables:
    score (float): The R^2 score of the model, representing the proportion 
                   of the variance in the dependent variable that is predictable 
                   from the independent variables.

Note:
    The R^2 score ranges from 0 to 1, where 1 indicates perfect prediction and 
    0 indicates that the model does not explain any of the variability in the data.
"""
print(f"model r^2 score: {score}")    # this values gives how much your model is accurate
# Out:
# model r^2 score: 1.0

# %%
pred=model.predict(X_test)
"""
Predicts the output for the test dataset and prints the predictions.

This function uses the trained model to predict the output for the test dataset `X_test`.
It then prints all the predicted values.

Variables:
    pred (numpy.ndarray): The predicted values for the test dataset.

Note:
    The slicing `pred[:]` is used to print all the predicted values. 
    You can modify the slicing to print a specific range of predictions.
"""
print(pred[:])              #:num gives the output for how many we want to find ,for only : all values wiil be displayed
# Out:
# [5.44000000e+05 5.84304262e-10 1.71250000e+06 3.65000000e+05
#  2.75000000e+05 6.25000000e+05 4.53000000e+05 3.00000000e+05
#  4.17985714e+05 6.72500000e+05 5.25000000e+05 5.00000000e+05
#  5.90000000e+05 3.05000000e+05 2.10000000e+05 9.15000000e+05
#  6.75000000e+05 6.30000000e+05 1.69000000e+06 8.83000000e+05
#  1.70000000e+06 6.12500000e+05 6.15000000e+05 5.90000000e+05
#  3.01500000e+05 8.75000000e+04 7.46000000e+05 9.50100000e+05
#  4.15000000e+05 7.75000000e+05 3.20000000e+06 2.53000000e+05
#  1.41500000e+06 3.12891000e+05 2.52000000e+05 3.25000000e+05
#  4.55000000e+05 5.40000000e+05 2.15000000e+05 6.53000000e+05
#  3.06000000e+05 4.35000000e+05 3.35000000e+05 6.10000000e+05
#  2.45000000e+05 3.65000000e+05 2.60000000e+05 6.15000000e+05
#  1.25000000e+06 8.35000000e+05 4.90000000e+05 4.82000000e+05
#  5.30000000e+05 5.50000000e+05 1.70000000e+05 6.15000000e+05
#  1.19500000e+06 5.89950000e+05 7.80000000e+05 3.32000000e+05
# ...
